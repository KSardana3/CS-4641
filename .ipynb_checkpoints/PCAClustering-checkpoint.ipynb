# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import OPTICS, cluster_optics_dbscan, DBSCAN
import statsmodels.tsa.stattools as ts

# %%
#initial dataset
priceData = pd.read_csv('all_stocks_5yr.csv')

# %%
#pre-processing
processed = pd.DataFrame()
for stock in np.unique(priceData["Name"]):
    df = pd.DataFrame()
    df = priceData.loc[priceData['Name'] == stock][['date','close']]
    df = df.transpose()
    df.columns = df.iloc[0]
    df = df.drop(df.index[0])
    df = df.rename(index={'close': stock})
    processed = pd.concat([processed, df])
processed
# Out:
# date 2013-02-08 2013-02-11 2013-02-12 2013-02-13 2013-02-14 2013-02-15  \
# A         45.08       44.6      44.62      44.75      44.58      42.25
# AAL       14.75      14.46      14.27      14.66      13.99       14.5
# AAP        78.9      78.39       78.6      78.97      78.84         79
# AAPL    67.8542    68.5614    66.8428    66.7156    66.6556    65.7371
# ABBV      36.25      35.85      35.42      35.27      36.57      37.58
# ...         ...        ...        ...        ...        ...        ...
# XYL       27.09      27.46      27.95      28.26      28.47      28.28
# YUM        65.3      64.55      64.75      64.41      63.89      63.99
# ZBH       75.85      75.65      75.44         76      76.34       75.9
# ZION      24.14      24.21      24.49      24.74      24.63      24.34
# ZTS       33.05      33.26      33.74      33.55      33.27      33.98
#
# date 2013-02-19 2013-02-20 2013-02-21 2013-02-22  ... 2018-01-25 2018-01-26  \
# ...

# %%
#calculating daily percent changes
dailyChange = processed.T.pct_change().T #calculate daily percent change
dailyChange = dailyChange.drop(['2013-02-08'], axis = 1) #needed because first column will be null due to percent change
dailyChange = dailyChange.dropna() #drop stocks that do not start at date: 2013-02-08
dailyChange.head()
# Out:
# date  2013-02-11  2013-02-12  2013-02-13  2013-02-14  2013-02-15  2013-02-19  \
# A      -0.010648    0.000448    0.002913   -0.003799   -0.052266    0.017988
# AAL    -0.019661   -0.013140    0.027330   -0.045703    0.036455   -0.016552
# AAP    -0.006464    0.002679    0.004707   -0.001646    0.002029    0.021772
# AAPL    0.010422   -0.025067   -0.001903   -0.000899   -0.013780   -0.000370
# ABBV   -0.011034   -0.011994   -0.004235    0.036859    0.027618    0.016232
#
# date  2013-02-20  2013-02-21  2013-02-22  2013-02-25  ...  2018-01-25  \
# A      -0.017903   -0.014441    0.004084   -0.012201  ...    0.003805
# AAL    -0.065217    0.003001    0.014959   -0.040531  ...   -0.031758
# AAP    -0.015114   -0.005535    0.001897   -0.010731  ...   -0.000579
# AAPL   -0.024218   -0.006216    0.010649   -0.017768  ...   -0.017851
# ABBV    0.010998    0.004403   -0.008252   -0.028341  ...    0.026443
#
# date  2018-01-26  2018-01-29  2018-01-30  2018-01-31  2018-02-01  2018-02-02  \
# ...

# %%
#performing PCA
pca_model = PCA(n_components = 300)
pca_model.fit(dailyChange.T)
pca_model.components_.T.shape
# Out:
# (476, 300)

# %%
dimReduced = pd.DataFrame(data = pca_model.components_.T, index = dailyChange.index)
dimReduced = dimReduced.add_prefix("P")
dimReduced.head()
# Out:
#             P0        P1        P2        P3        P4        P5        P6  \
# A    -0.052106 -0.016433  0.016918 -0.039732  0.005226  0.010964  0.027433
# AAL  -0.061322 -0.056385  0.066372 -0.005943 -0.025348 -0.082605 -0.081006
# AAP  -0.040687 -0.022934 -0.004541  0.085317 -0.076211 -0.025629  0.028174
# AAPL -0.035636 -0.017763  0.010961 -0.046832  0.033141 -0.035528  0.042766
# ABBV -0.044225 -0.031625 -0.002505 -0.052149 -0.076562  0.068573 -0.014592
#
#             P7        P8        P9  ...      P290      P291      P292  \
# A    -0.008240  0.024950 -0.014855  ... -0.008670  0.102123 -0.033881
# AAL  -0.187892 -0.238921 -0.017287  ...  0.081073 -0.043683 -0.057959
# AAP   0.019684 -0.008664  0.006423  ... -0.002337 -0.029274 -0.002166
# AAPL -0.003001 -0.004477 -0.017915  ...  0.036929  0.017949  0.023417
# ABBV  0.013716  0.023300  0.008433  ...  0.013467  0.000697  0.046005
#
#           P293      P294      P295      P296      P297      P298      P299
# ...

# %%
optics_model = OPTICS(min_samples = 3, xi = 0.04) #can change or add more parameters
optics_model.fit(dimReduced) #training the model
# Out:
# OPTICS(min_samples=3, xi=0.04)

# %%
labels = optics_model.labels_ #each point's cluster label
number_of_clusters = len(set(labels)) - (1 if -1 in labels else 0)
print("Number of clusers: " + str(number_of_clusters))
# Out:
# Number of clusers: 6

# %%
#OPTICS Plot
colors = ['c.', 'b.', 'r.', 'y.', 'g.','m.']
for currClass, color in zip(range(0, 6), colors):
    Xk = dailyChange[optics_model.labels_ == currClass]
    plt.plot(Xk.iloc[:, 0], Xk.iloc[:, 1], color, alpha = 1)
plt.ylim([-.03,.08])
plt.plot(dailyChange.iloc[optics_model.labels_ == -1, 0], dailyChange.iloc[optics_model.labels_ == -1, 1], 'k+', alpha = 0.07)

# %%
#example of 3 stocks from cluster 0
index = np.where(labels == 0)
plt.plot(processed.iloc[index[0][0]].index,processed.iloc[index[0][0]].values, c='r')
plt.plot(processed.iloc[index[0][0]].index,processed.iloc[index[0][1]].values, c='b')
plt.plot(processed.iloc[index[0][0]].index,processed.iloc[index[0][2]].values, c='g')
plt.show()

# %%
#used to locate cointegrated pairs in different clusters
index = np.where(labels == 3)
high = 1
x = 0
y = 0
for i in range(len(index[0])):
    for j in range(len(index[0])):
        if i == j:
            continue
        subtraction = processed.iloc[index[0][i]].values - processed.iloc[index[0][j]].values
        #dicky fuller test performed to find cointegration
        results = ts.adfuller(subtraction)
        if results[1] < high:
            x = i
            y = j
            high = results[1]
print(x,y,high)
# Out:
# 0 2 0.0720554378574973

# %%
#resulting pairs
listOfPairs = [[22,155],[318,380]]

# %%
#plotting pairs 22 and 155
plt.plot(processed.iloc[index[0][0]].index,processed.iloc[22].values, c='r')
plt.plot(processed.iloc[index[0][0]].index,processed.iloc[155].values, c='b')
plt.show()

# %%
#plotting pairs 318 and 380
plt.plot(processed.iloc[index[0][0]].index,processed.iloc[318].values, c='r')
plt.plot(processed.iloc[index[0][0]].index,processed.iloc[380].values, c='b')
plt.show()
